# %% [markdown]
# <a href="https://colab.research.google.com/github/chabpre/dataprovisual/blob/main/Quiz_30.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pa
import matplotlib.pyplot as plt
import seaborn as sns

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/bank.csv')

# %% [markdown]
# These are the two that i believe will appear on the final test

# %%
ax = sns.heatmap(df.corr(),vmin = -1)
ax.set(title = 'Heatmap of Banking')

plt.show()

# %%
ax = df.duration.hist(bins = 25)
ax.set(title = "Histogram of Duration")
plt.show()
