# %% [markdown]
# <a href="https://colab.research.google.com/github/chabpre/dataprovisual/blob/main/RecentVisualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Recent Visualizations
# Charles Presley
#
# ECU ID: 236587
#
# Class: Data Process Visualization

# %% [markdown]
# The following is going to be over the atlas of moons all the way to pluto at least the ones that are known. ![atlas](https://astrobiology.nasa.gov/nai/media/Nat_Geo_Altlas_of_Moons.png) (picture is taken from the https://www.nationalgeographic.com/science/graphics/the-atlas-of-moons)

# %% [markdown]
# Every planet in the following I am going to be talking about the major moons that are known, if not I would be trying to list of all 79 moons that orbit around Jupitar and the 82 that orbit around Saturn. So for this i will be sticking to the major moons

# %% [markdown]
# Starting with the Earth has one moon that we all know about and see it everynight for the most part. Mars has 2 moons, Phobos and Deimos, Jupitar has 4, Io, Europa, Ganymede, and Callisto. Saturn has 7, Mimas, Enceladus, Tethys, Dione, Rhea, Titan, and Lapetus, Uranus has 5, Miranda, Ariel, Umbriel, Titania, and Oberon.
#
# The last 2 planets only have 1 major moon, Neptune has Triton and Pluto has Charon

# %% [markdown]
# Now i want to talk about why i just covered the major moons. The major moons are the ones that are closly orbiting the planet. the minor moons orbit at all different directions and is hard to keep up when the planet has 79 moons in total. The moons around Jupitar and Saturn are farther from the planet than the major moons i talked mentioned above.
# ![Screenshot 2022-05-06 121651.png](data:image/png;base64,...)

# %% [markdown]
# The above picture is all the moons minor and major that orbit around Jupitar and wow i did not realize that there were that many i really only knew about the 4 major ones.

# %% [markdown]
# Galileo Galilei made the first telescopic observation of the moon in 1610, later with the same telescope he found that Jupitar also had 4 moons orbiting around it. In 1655 Christiaan Huygens discovered the largest moon that orbits around Saturnm, Titan, later between 1671 and 1684 Giovanni Domenico Cassini discovered Tethys, Dione, Rhea and Iapetus. Over the years there have been many moons discovered and new technology to help discover the moons.

# %% [markdown]
# I have learned in the research of this that there are alot of moons in our solar system. I hope to do more research to better understand the moons and what effects they have on the planet.

# %% [markdown]
# The following websites I used for this projects
#
# https://www.nationalgeographic.com/science/graphics/the-atlas-of-moons
#
# https://en.wikipedia.org/wiki/Moons_of_Saturn#:~:text=Saturn's%20largest%20moon%2C%20Titan%2C%20was,1684%20by%20Giovanni%20Domenico%20Cassini.
#
# https://www.nationalgeographic.org/thisday/jan7/galileo-discovers-jupiters-moons/#:~:text=Background%20Info%20Vocabulary-,On%20January%207%2C%201610%2C%20Italian%20astronomer%20Galileo%20Galilei%20discovered%2C,move%20in%20a%20regular%20pattern.
