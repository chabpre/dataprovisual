# %% [markdown]
# <a href="https://colab.research.google.com/github/chabpre/dataprovisual/blob/main/Quiz_17_Ints_and_Floats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PedalLength  PedalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.SepalLength.mean()
# Out:
# 5.843333333333335

# %%
df2 = df.SepalLength.astype('int')
df2
# Out:
# 0      5
# 1      4
# 2      4
# 3      4
# 4      5
#       ..
# 145    6
# 146    6
# 147    6
# 148    6
# 149    5
# Name: SepalLength, Length: 150, dtype: int64

# %%
df.SepalLength.mean()
# Out:
# 5.843333333333335

# %% [markdown]
# Changing the length from a float to an int changed the value of the decimal

# %%
df
# Out:
#      SepalLength  SepalWidth  PedalLength  PedalWidth           Class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.groupby("Class").head()
# Out:
#      SepalLength  SepalWidth  PedalLength  PedalWidth            Class
# 0            5.1         3.5          1.4         0.2      Iris-setosa
# 1            4.9         3.0          1.4         0.2      Iris-setosa
# 2            4.7         3.2          1.3         0.2      Iris-setosa
# 3            4.6         3.1          1.5         0.2      Iris-setosa
# 4            5.0         3.6          1.4         0.2      Iris-setosa
# 50           7.0         3.2          4.7         1.4  Iris-versicolor
# 51           6.4         3.2          4.5         1.5  Iris-versicolor
# 52           6.9         3.1          4.9         1.5  Iris-versicolor
# 53           5.5         2.3          4.0         1.3  Iris-versicolor
# 54           6.5         2.8          4.6         1.5  Iris-versicolor
# 100          6.3         3.3          6.0         2.5   Iris-virginica
# 101          5.8         2.7          5.1         1.9   Iris-virginica
# ...

# %% [markdown]
# Both the outputs above look similar to me and there is not a change you are just seeing the other class rather than it being scaled behind for too many lists items

# %%
df.groupby("Class").describe()
# Out:
#                 SepalLength                        ... PedalWidth
#                       count   mean       std  min  ...        25%  50%  75%  max
# Class                                              ...
# Iris-setosa            50.0  5.006  0.352490  4.3  ...        0.2  0.2  0.3  0.6
# Iris-versicolor        50.0  5.936  0.516171  4.9  ...        1.2  1.3  1.5  1.8
# Iris-virginica         50.0  6.588  0.635880  4.9  ...        1.8  2.0  2.3  2.5
#
# [3 rows x 32 columns]
