# %% [markdown]
# <a href="https://colab.research.google.com/github/chabpre/dataprovisual/blob/main/Quiz11_Twitter_Api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 1.7 MB/s
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp drive/MyDrive/config.py .

# %%
import config
import twitter
CONSUMER_KEY = config.CONSUMER_KEY
CONSUMER_SECRET = config.CONSUMER_SECRET
OAUTH_TOKEN = config.OAUTH_TOKEN
OAUTH_TOKEN_SECRET = config.OAUTH_TOKEN_SECRET
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

mathcs_twitter_api = twitter.Twitter(auth=auth)

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = mathcs_twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = mathcs_twitter_api.trends.place(_id=US_WOE_ID)

for i in range(10):
    print(world_trends[0]['trends'][i]['query'])
# Out:
# Bruna
# B%C3%A1rbara
# %23jogodadiscordia
# %22O+Arthur%22
# %23TheBachelor
# %23WWERaw
# %22Arthur+Aguiar%22
# VERNON
# Juliette
# Donovan

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json


q = '#CallofDuty'

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = mathcs_twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = mathcs_twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Streaming output truncated to the last 5000 lines.
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 978750044143783936,
#             "id_str": "978750044143783936",
#             "name": "oz",
#             "screen_name": "lxszlm",
#             "location": "disappearing",
#             "description": "le mal du ciel (and some streaming on the side)",
#             "url": "https://t.co/681rxOMNpb",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/681rxOMNpb",
#                             "expanded_url": "https://yugoslavicbaby.tumblr.com",
#                             "display_url": "yugoslavicbaby.tumblr.com",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 267,
#             "friends_count": 359,
#             "listed_count": 0,
#             "created_at": "Tue Mar 27 21:46:09 +0000 2018",
#             "favourites_count": 101875,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 4784,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1457859766588350470/GZfW0el__normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1457859766588350470/GZfW0el__normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/978750044143783936/1636415830",
#             "profile_link_color": "666666",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Tue Feb 08 00:55:40 +0000 2022",
#             "id": 1490851792178978819,
#             "id_str": "1490851792178978819",
#             "text": "https://t.co/7uDtkxUfrG come chat n watch me grind for a few hrs &lt;3 #stream #SmallStreamersConnect #smallstreamer\u2026 https://t.co/U8LQI9WFXx",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "stream",
#                         "indices": [
#                             71,
#                             78
#                         ]
#                     },
#                     {
#                         "text": "SmallStreamersConnect",
#                         "indices": [
#                             79,
#                             101
#                         ]
#                     },
#                     {
#                         "text": "smallstreamer",
#                         "indices": [
#                             102,
#                             116
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/7uDtkxUfrG",
#                         "expanded_url": "https://www.twitch.tv/ozmonaut",
#                         "display_url": "twitch.tv/ozmonaut",
#                         "indices": [
#                             0,
#                             23
#                         ]
#                     },
#                     {
#                         "url": "https://t.co/U8LQI9WFXx",
#                         "expanded_url": "https://twitter.com/i/web/status/1490851792178978819",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             118,
#                             141
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 978750044143783936,
#                 "id_str": "978750044143783936",
#                 "name": "oz",
#                 "screen_name": "lxszlm",
#                 "location": "disappearing",
#                 "description": "le mal du ciel (and some streaming on the side)",
#                 "url": "https://t.co/681rxOMNpb",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/681rxOMNpb",
#                                 "expanded_url": "https://yugoslavicbaby.tumblr.com",
#                                 "display_url": "yugoslavicbaby.tumblr.com",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 267,
#                 "friends_count": 359,
#                 "listed_count": 0,
#                 "created_at": "Tue Mar 27 21:46:09 +0000 2018",
#                 "favourites_count": 101875,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": false,
#                 "statuses_count": 4784,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1457859766588350470/GZfW0el__normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1457859766588350470/GZfW0el__normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/978750044143783936/1636415830",
#                 "profile_link_color": "666666",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": true,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 1,
#             "favorite_count": 3,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Feb 08 02:05:40 +0000 2022",
#         "id": 1490869408264249347,
#         "id_str": "1490869408264249347",
#         "text": "Combat Shield Completed. 28/38 Weapons Done. #PS4Share #CallOfDuty #Vanguard #GrindToAtomic #Twitch https://t.co/9b00tq4q7D",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "PS4Share",
#                     "indices": [
#                         45,
#                         54
#                     ]
#                 },
#                 {
#                     "text": "CallOfDuty",
#                     "indices": [
#                         55,
#                         66
#                     ]
#                 },
#                 {
#                     "text": "Vanguard",
#                     "indices": [
#                         67,
#                         76
#                     ]
#                 },
#                 {
#                     "text": "GrindToAtomic",
#                     "indices": [
#                         77,
#                         91
#                     ]
#                 },
#                 {
#                     "text": "Twitch",
#                     "indices": [
#                         92,
#                         99
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490869405336621056,
#                     "id_str": "1490869405336621056",
#                     "indices": [
#                         100,
#                         123
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLCh0z-WUAA0y9c.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLCh0z-WUAA0y9c.jpg",
#                     "url": "https://t.co/9b00tq4q7D",
#                     "display_url": "pic.twitter.com/9b00tq4q7D",
#                     "expanded_url": "https://twitter.com/Devondaking101/status/1490869408264249347/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490869405336621056,
#                     "id_str": "1490869405336621056",
#                     "indices": [
#                         100,
#                         123
#                     ],
#                     "media_url": "http://pbs.twimg.com/media/FLCh0z-WUAA0y9c.jpg",
#                     "media_url_https": "https://pbs.twimg.com/media/FLCh0z-WUAA0y9c.jpg",
#                     "url": "https://t.co/9b00tq4q7D",
#                     "display_url": "pic.twitter.com/9b00tq4q7D",
#                     "expanded_url": "https://twitter.com/Devondaking101/status/1490869408264249347/photo/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "large": {
#                             "w": 2048,
#                             "h": 1152,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://www.playstation.com\" rel=\"nofollow\">PlayStation\u00aeNetwork</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1392505414948986882,
#             "id_str": "1392505414948986882",
#             "name": "Devon",
#             "screen_name": "Devondaking101",
#             "location": "",
#             "description": "Let\u2019s Have Some Fun! \ud83d\udd79\ud83c\udfae\ud83d\ude08",
#             "url": "https://t.co/gGfvxKyxHA",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/gGfvxKyxHA",
#                             "expanded_url": "https://www.twitch.tv/devondaking",
#                             "display_url": "twitch.tv/devondaking",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 65,
#             "friends_count": 78,
#             "listed_count": 0,
#             "created_at": "Wed May 12 15:42:54 +0000 2021",
#             "favourites_count": 83,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 385,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1392505979426775048/WZikxQCX_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1392505979426775048/WZikxQCX_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1392505414948986882/1625442470",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Feb 08 02:05:35 +0000 2022",
#         "id": 1490869388521607170,
#         "id_str": "1490869388521607170",
#         "text": "RT @itsnotjayboi: I hit em w the 3 piece combo #warzone #rebirthisland #callofduty #twitch https://t.co/4xLtsDdklb",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "warzone",
#                     "indices": [
#                         47,
#                         55
#                     ]
#                 },
#                 {
#                     "text": "rebirthisland",
#                     "indices": [
#                         56,
#                         70
#                     ]
#                 },
#                 {
#                     "text": "callofduty",
#                     "indices": [
#                         71,
#                         82
#                     ]
#                 },
#                 {
#                     "text": "twitch",
#                     "indices": [
#                         83,
#                         90
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "itsnotjayboi",
#                     "name": "Notjayboi",
#                     "id": 2150839198,
#                     "id_str": "2150839198",
#                     "indices": [
#                         3,
#                         16
#                     ]
#                 }
#             ],
#             "urls": [],
#             "media": [
#                 {
#                     "id": 1490560709293453314,
#                     "id_str": "1490560709293453314",
#                     "indices": [
#                         91,
#                         114
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1490560709293453314/pu/img/9SPrfRDPVoCKsDU1.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1490560709293453314/pu/img/9SPrfRDPVoCKsDU1.jpg",
#                     "url": "https://t.co/4xLtsDdklb",
#                     "display_url": "pic.twitter.com/4xLtsDdklb",
#                     "expanded_url": "https://twitter.com/itsnotjayboi/status/1490560756072554496/video/1",
#                     "type": "photo",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1280,
#                             "h": 720,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490560756072554496,
#                     "source_status_id_str": "1490560756072554496",
#                     "source_user_id": 2150839198,
#                     "source_user_id_str": "2150839198"
#                 }
#             ]
#         },
#         "extended_entities": {
#             "media": [
#                 {
#                     "id": 1490560709293453314,
#                     "id_str": "1490560709293453314",
#                     "indices": [
#                         91,
#                         114
#                     ],
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1490560709293453314/pu/img/9SPrfRDPVoCKsDU1.jpg",
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1490560709293453314/pu/img/9SPrfRDPVoCKsDU1.jpg",
#                     "url": "https://t.co/4xLtsDdklb",
#                     "display_url": "pic.twitter.com/4xLtsDdklb",
#                     "expanded_url": "https://twitter.com/itsnotjayboi/status/1490560756072554496/video/1",
#                     "type": "video",
#                     "sizes": {
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "medium": {
#                             "w": 1200,
#                             "h": 675,
#                             "resize": "fit"
#                         },
#                         "small": {
#                             "w": 680,
#                             "h": 383,
#                             "resize": "fit"
#                         },
#                         "large": {
#                             "w": 1280,
#                             "h": 720,
#                             "resize": "fit"
#                         }
#                     },
#                     "source_status_id": 1490560756072554496,
#                     "source_status_id_str": "1490560756072554496",
#                     "source_user_id": 2150839198,
#                     "source_user_id_str": "2150839198",
#                     "video_info": {
#                         "aspect_ratio": [
#                             16,
#                             9
#                         ],
#                         "duration_millis": 12851,
#                         "variants": [
#                             {
#                                 "bitrate": 2176000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1490560709293453314/pu/vid/1280x720/dh_ACi_10T9IiSie.mp4?tag=12"
#                             },
#                             {
#                                 "bitrate": 832000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1490560709293453314/pu/vid/640x360/dy9VW4znL-DLqT0l.mp4?tag=12"
#                             },
#                             {
#                                 "content_type": "application/x-mpegURL",
#                                 "url": "https://video.twimg.com/ext_tw_video/1490560709293453314/pu/pl/P9XtheEWpkfYfUv5.m3u8?tag=12&container=fmp4"
#                             },
#                             {
#                                 "bitrate": 256000,
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/1490560709293453314/pu/vid/480x270/S6ac7OYFPt4V3DJL.mp4?tag=12"
#                             }
#                         ]
#                     },
#                     "additional_media_info": {
#                         "monetizable": false,
#                         "source_user": {
#                             "id": 2150839198,
#                             "id_str": "2150839198",
#                             "name": "Notjayboi",
#                             "screen_name": "itsnotjayboi",
#                             "location": "New Jersey, USA",
#                             "description": "22 | Content Creator | Twitch Streamer | Professional Vibe Setter",
#                             "url": "https://t.co/0hoWzHl3W3",
#                             "entities": {
#                                 "url": {
#                                     "urls": [
#                                         {
#                                             "url": "https://t.co/0hoWzHl3W3",
#                                             "expanded_url": "https://linktr.ee/Notbjames",
#                                             "display_url": "linktr.ee/Notbjames",
#                                             "indices": [
#                                                 0,
#                                                 23
#                                             ]
#                                         }
#                                     ]
#                                 },
#                                 "description": {
#                                     "urls": []
#                                 }
#                             },
#                             "protected": false,
#                             "followers_count": 60,
#                             "friends_count": 241,
#                             "listed_count": 2,
#                             "created_at": "Thu Oct 24 10:29:04 +0000 2013",
#                             "favourites_count": 692,
#                             "utc_offset": null,
#                             "time_zone": null,
#                             "geo_enabled": false,
#                             "verified": false,
#                             "statuses_count": 853,
#                             "lang": null,
#                             "contributors_enabled": false,
#                             "is_translator": false,
#                             "is_translation_enabled": false,
#                             "profile_background_color": "C0DEED",
#                             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_background_tile": false,
#                             "profile_image_url": "http://pbs.twimg.com/profile_images/1465949010334789633/cL_V6VTR_normal.jpg",
#                             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1465949010334789633/cL_V6VTR_normal.jpg",
#                             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2150839198/1615449748",
#                             "profile_link_color": "1DA1F2",
#                             "profile_sidebar_border_color": "C0DEED",
#                             "profile_sidebar_fill_color": "DDEEF6",
#                             "profile_text_color": "333333",
#                             "profile_use_background_image": true,
#                             "has_extended_profile": true,
#                             "default_profile": true,
#                             "default_profile_image": false,
#                             "following": false,
#                             "follow_request_sent": false,
#                             "notifications": false,
#                             "translator_type": "none",
#                             "withheld_in_countries": []
#                         }
#                     }
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1256349602493718531,
#             "id_str": "1256349602493718531",
#             "name": "Jeremiah",
#             "screen_name": "KingVJames_",
#             "location": "",
#             "description": "Competitive FPS Player | Deep thinker | Have no regrets\ud83d\udd25",
#             "url": "https://t.co/LIivdc6b32",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/LIivdc6b32",
#                             "expanded_url": "https://m.twitch.tv/kingvjames",
#                             "display_url": "m.twitch.tv/kingvjames",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 35,
#             "friends_count": 154,
#             "listed_count": 1,
#             "created_at": "Fri May 01 22:28:02 +0000 2020",
#             "favourites_count": 1289,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 1061,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1471740538504323073/pgihqs7J_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1471740538504323073/pgihqs7J_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1256349602493718531/1627363108",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 05:39:12 +0000 2022",
#             "id": 1490560756072554496,
#             "id_str": "1490560756072554496",
#             "text": "I hit em w the 3 piece combo #warzone #rebirthisland #callofduty #twitch https://t.co/4xLtsDdklb",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "warzone",
#                         "indices": [
#                             29,
#                             37
#                         ]
#                     },
#                     {
#                         "text": "rebirthisland",
#                         "indices": [
#                             38,
#                             52
#                         ]
#                     },
#                     {
#                         "text": "callofduty",
#                         "indices": [
#                             53,
#                             64
#                         ]
#                     },
#                     {
#                         "text": "twitch",
#                         "indices": [
#                             65,
#                             72
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1490560709293453314,
#                         "id_str": "1490560709293453314",
#                         "indices": [
#                             73,
#                             96
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1490560709293453314/pu/img/9SPrfRDPVoCKsDU1.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1490560709293453314/pu/img/9SPrfRDPVoCKsDU1.jpg",
#                         "url": "https://t.co/4xLtsDdklb",
#                         "display_url": "pic.twitter.com/4xLtsDdklb",
#                         "expanded_url": "https://twitter.com/itsnotjayboi/status/1490560756072554496/video/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1280,
#                                 "h": 720,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1490560709293453314,
#                         "id_str": "1490560709293453314",
#                         "indices": [
#                             73,
#                             96
#                         ],
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1490560709293453314/pu/img/9SPrfRDPVoCKsDU1.jpg",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1490560709293453314/pu/img/9SPrfRDPVoCKsDU1.jpg",
#                         "url": "https://t.co/4xLtsDdklb",
#                         "display_url": "pic.twitter.com/4xLtsDdklb",
#                         "expanded_url": "https://twitter.com/itsnotjayboi/status/1490560756072554496/video/1",
#                         "type": "video",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 1280,
#                                 "h": 720,
#                                 "resize": "fit"
#                             }
#                         },
#                         "video_info": {
#                             "aspect_ratio": [
#                                 16,
#                                 9
#                             ],
#                             "duration_millis": 12851,
#                             "variants": [
#                                 {
#                                     "bitrate": 2176000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1490560709293453314/pu/vid/1280x720/dh_ACi_10T9IiSie.mp4?tag=12"
#                                 },
#                                 {
#                                     "bitrate": 832000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1490560709293453314/pu/vid/640x360/dy9VW4znL-DLqT0l.mp4?tag=12"
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/1490560709293453314/pu/pl/P9XtheEWpkfYfUv5.m3u8?tag=12&container=fmp4"
#                                 },
#                                 {
#                                     "bitrate": 256000,
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/1490560709293453314/pu/vid/480x270/S6ac7OYFPt4V3DJL.mp4?tag=12"
#                                 }
#                             ]
#                         },
#                         "additional_media_info": {
#                             "monetizable": false
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 2150839198,
#                 "id_str": "2150839198",
#                 "name": "Notjayboi",
#                 "screen_name": "itsnotjayboi",
#                 "location": "New Jersey, USA",
#                 "description": "22 | Content Creator | Twitch Streamer | Professional Vibe Setter",
#                 "url": "https://t.co/0hoWzHl3W3",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/0hoWzHl3W3",
#                                 "expanded_url": "https://linktr.ee/Notbjames",
#                                 "display_url": "linktr.ee/Notbjames",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 60,
#                 "friends_count": 241,
#                 "listed_count": 2,
#                 "created_at": "Thu Oct 24 10:29:04 +0000 2013",
#                 "favourites_count": 692,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 853,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "C0DEED",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1465949010334789633/cL_V6VTR_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1465949010334789633/cL_V6VTR_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/2150839198/1615449748",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 1,
#             "favorite_count": 5,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Tue Feb 08 02:04:49 +0000 2022",
#         "id": 1490869195394846722,
#         "id_str": "1490869195394846722",
#         "text": "RT @sieteswave: game winning finisher \ud83e\udd2b\n\n#callofduty #warzone #cod #2kfreeagent #gaming #gamer #streaming #rebirthisland  https://t.co/s9nU\u2026",
#         "truncated": false,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "callofduty",
#                     "indices": [
#                         41,
#                         52
#                     ]
#                 },
#                 {
#                     "text": "warzone",
#                     "indices": [
#                         53,
#                         61
#                     ]
#                 },
#                 {
#                     "text": "cod",
#                     "indices": [
#                         62,
#                         66
#                     ]
#                 },
#                 {
#                     "text": "2kfreeagent",
#                     "indices": [
#                         67,
#                         79
#                     ]
#                 },
#                 {
#                     "text": "gaming",
#                     "indices": [
#                         80,
#                         87
#                     ]
#                 },
#                 {
#                     "text": "gamer",
#                     "indices": [
#                         88,
#                         94
#                     ]
#                 },
#                 {
#                     "text": "streaming",
#                     "indices": [
#                         95,
#                         105
#                     ]
#                 },
#                 {
#                     "text": "rebirthisland",
#                     "indices": [
#                         106,
#                         120
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "sieteswave",
#                     "name": "SietesWave\u2122\ufe0f Gaming",
#                     "id": 1223652258371571720,
#                     "id_str": "1223652258371571720",
#                     "indices": [
#                         3,
#                         14
#                     ]
#                 }
#             ],
#             "urls": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 51668304,
#             "id_str": "51668304",
#             "name": "$iete I",
#             "screen_name": "ohmiikey",
#             "location": "\ud83d\udc7bohmiikey",
#             "description": "non-opinionated, please dont ask me how I feel about it @sieteswave \ud83c\udfdd\u2800\u2800\u2800\u2800\u2800\u2800\u2800\u2800\u2800",
#             "url": "https://t.co/thcoMdpvDE",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/thcoMdpvDE",
#                             "expanded_url": "https://bio.site/sieteswave",
#                             "display_url": "bio.site/sieteswave",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 2251,
#             "friends_count": 1093,
#             "listed_count": 80,
#             "created_at": "Sun Jun 28 06:25:23 +0000 2009",
#             "favourites_count": 1570,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 76925,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "DBE9ED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#             "profile_background_tile": true,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1486686085069606914/D6uZs891_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1486686085069606914/D6uZs891_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/51668304/1634527649",
#             "profile_link_color": "050505",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "3D3C36",
#             "profile_text_color": "B2C2AE",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Tue Feb 08 02:04:41 +0000 2022",
#             "id": 1490869159089090560,
#             "id_str": "1490869159089090560",
#             "text": "game winning finisher \ud83e\udd2b\n\n#callofduty #warzone #cod #2kfreeagent #gaming #gamer #streaming #rebirthisland  https://t.co/s9nU4XnEE0",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "callofduty",
#                         "indices": [
#                             25,
#                             36
#                         ]
#                     },
#                     {
#                         "text": "warzone",
#                         "indices": [
#                             37,
#                             45
#                         ]
#                     },
#                     {
#                         "text": "cod",
#                         "indices": [
#                             46,
# ...
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1212764317889773568/rKD1HNlf_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1212764317889773568/rKD1HNlf_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/812077337898586112/1536501821",
#             "profile_link_color": "91D2FA",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Mon Feb 07 14:22:57 +0000 2022",
#             "id": 1490692561505239045,
#             "id_str": "1490692561505239045",
#             "text": "Call of Duty Vanguard et Warzone Saison 2\nEst-ce que \u00e7a va changer quelques chose ?\n#CallofDuty #Vanguard #Warzone https://t.co/W2Pl1FQ9fx",
#             "truncated": false,
#             "entities": {
#                 "hashtags": [
#                     {
#                         "text": "CallofDuty",
#                         "indices": [
#                             84,
#                             95
#                         ]
#                     },
#                     {
#                         "text": "Vanguard",
#                         "indices": [
#                             96,
#                             105
#                         ]
#                     },
#                     {
#                         "text": "Warzone",
#                         "indices": [
#                             106,
#                             114
#                         ]
#                     }
#                 ],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [],
#                 "media": [
#                     {
#                         "id": 1490692552894390279,
#                         "id_str": "1490692552894390279",
#                         "indices": [
#                             115,
#                             138
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLAA-pSXIAcsqBs.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLAA-pSXIAcsqBs.jpg",
#                         "url": "https://t.co/W2Pl1FQ9fx",
#                         "display_url": "pic.twitter.com/W2Pl1FQ9fx",
#                         "expanded_url": "https://twitter.com/FRSkyRRoZ/status/1490692561505239045/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "id": 1490692552894390279,
#                         "id_str": "1490692552894390279",
#                         "indices": [
#                             115,
#                             138
#                         ],
#                         "media_url": "http://pbs.twimg.com/media/FLAA-pSXIAcsqBs.jpg",
#                         "media_url_https": "https://pbs.twimg.com/media/FLAA-pSXIAcsqBs.jpg",
#                         "url": "https://t.co/W2Pl1FQ9fx",
#                         "display_url": "pic.twitter.com/W2Pl1FQ9fx",
#                         "expanded_url": "https://twitter.com/FRSkyRRoZ/status/1490692561505239045/photo/1",
#                         "type": "photo",
#                         "sizes": {
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "medium": {
#                                 "w": 1200,
#                                 "h": 675,
#                                 "resize": "fit"
#                             },
#                             "small": {
#                                 "w": 680,
#                                 "h": 383,
#                                 "resize": "fit"
#                             },
#                             "large": {
#                                 "w": 2048,
#                                 "h": 1152,
#                                 "resize": "fit"
#                             }
#                         }
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "fr",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 512701026,
#                 "id_str": "512701026",
#                 "name": "Skyrroz",
#                 "screen_name": "FRSkyRRoZ",
#                 "location": "Jalisco, M\u00e9xico",
#                 "description": "Je joue la com\u00e9die sur des jeux vid\u00e9o \ud83c\udfachttps://t.co/w1mlOWGktx \ud83c\udfae https://t.co/nRRqSwFkVY Sponsored by @ScufFrance @TurtleBeachFr \ud83c\uddeb\ud83c\uddf7\ud83c\uddf2\ud83c\uddfd\ud83c\uddfa\ud83c\uddf8",
#                 "url": "https://t.co/w1mlOWGktx",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/w1mlOWGktx",
#                                 "expanded_url": "http://bit.ly/FRSkyRRoZ",
#                                 "display_url": "bit.ly/FRSkyRRoZ",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/w1mlOWGktx",
#                                 "expanded_url": "http://bit.ly/FRSkyRRoZ",
#                                 "display_url": "bit.ly/FRSkyRRoZ",
#                                 "indices": [
#                                     39,
#                                     62
#                                 ]
#                             },
#                             {
#                                 "url": "https://t.co/nRRqSwFkVY",
#                                 "expanded_url": "http://twitch.tv/skyrroztv",
#                                 "display_url": "twitch.tv/skyrroztv",
#                                 "indices": [
#                                     65,
#                                     88
#                                 ]
#                             }
#                         ]
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 568722,
#                 "friends_count": 714,
#                 "listed_count": 255,
#                 "created_at": "Sat Mar 03 02:39:12 +0000 2012",
#                 "favourites_count": 18066,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": true,
#                 "verified": true,
#                 "statuses_count": 37948,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "000000",
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme5/bg.gif",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme5/bg.gif",
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1490409277181214723/HUNG7Ubf_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1490409277181214723/HUNG7Ubf_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/512701026/1615462832",
#                 "profile_link_color": "DD2E44",
#                 "profile_sidebar_border_color": "000000",
#                 "profile_sidebar_fill_color": "000000",
#                 "profile_text_color": "000000",
#                 "profile_use_background_image": false,
#                 "has_extended_profile": false,
#                 "default_profile": false,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "regular",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 14,
#             "favorite_count": 299,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "fr"
#         },
#         "is_quote_status": false,
#         "retweet_count": 14,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "fr"
#     },
#     {
#         "created_at": "Tue Feb 08 01:58:54 +0000 2022",
#         "id": 1490867704110075904,
#         "id_str": "1490867704110075904",
#         "text": "I probably would be really good in #ApexLegends #Arenas with my history with #CSGO  but don't have a #squad to run\u2026 https://t.co/07kwqTHQry",
#         "truncated": true,
#         "entities": {
#             "hashtags": [
#                 {
#                     "text": "ApexLegends",
#                     "indices": [
#                         35,
#                         47
#                     ]
#                 },
#                 {
#                     "text": "Arenas",
#                     "indices": [
#                         48,
#                         55
#                     ]
#                 },
#                 {
#                     "text": "CSGO",
#                     "indices": [
#                         77,
#                         82
#                     ]
#                 },
#                 {
#                     "text": "squad",
#                     "indices": [
#                         101,
#                         107
#                     ]
#                 }
#             ],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/07kwqTHQry",
#                     "expanded_url": "https://twitter.com/i/web/status/1490867704110075904",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         116,
#                         139
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 3019413886,
#             "id_str": "3019413886",
#             "name": "Snipes",
#             "screen_name": "SnipesGaming_",
#             "location": "Canada",
#             "description": "Father, Canadian Variety Streamer \ud83c\udde8\ud83c\udde6\n@Twitch affiliated  follow all my socials :) SnipesGaming_\nsponsored through @soesic_clothing \ncode: S69G at check out",
#             "url": "https://t.co/0JCRj2Ochs",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/0JCRj2Ochs",
#                             "expanded_url": "https://www.twitch.tv/snipesgaming_",
#                             "display_url": "twitch.tv/snipesgaming_",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 161,
#             "friends_count": 142,
#             "listed_count": 1,
#             "created_at": "Thu Feb 05 05:12:48 +0000 2015",
#             "favourites_count": 413,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 3287,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "000000",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1261450155959758848/HUtJHhPW_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1261450155959758848/HUtJHhPW_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/3019413886/1589587906",
#             "profile_link_color": "4A913C",
#             "profile_sidebar_border_color": "000000",
#             "profile_sidebar_fill_color": "000000",
#             "profile_text_color": "000000",
#             "profile_use_background_image": false,
#             "has_extended_profile": true,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 0,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "lang": "en"
#     }
# ]
